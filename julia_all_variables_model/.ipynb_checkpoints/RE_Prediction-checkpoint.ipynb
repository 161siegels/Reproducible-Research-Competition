# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("scaled_train.csv")
test = pd.read_csv("scaled_test.csv")
fix = pd.read_csv("fixed_effects_fixed.csv")
re = pd.read_csv("random_effects_fixed.csv")

# %%
test_ordered = test
test_ordered["Intercept"] = 1

# %%
test_ordered = test_ordered[
    ["Intercept","FG_Percent", "FT_Percent", "FG3_Percent", "layup", "dunk", 
     "hook", "fadeaway", "pullup", "running", "driving", "reverse", 
     "fingerroll", "putback", "turnaround", "bank", "point_diff", 
     "tip", "TOUCH_TIME", "DRIBBLES", "ratio", "jump_shot", "End_SC", 
     "End_PC", "LOCATION", "Quick_S", "Clutch_T", "Garbage_T", 
     "SHOT_CLOCK", "SHOT_NUMBER", "SHOT_RESULT2", "player_name"]
]
test_ordered.head()
# Out:
#    Intercept  FG_Percent  FT_Percent  FG3_Percent     layup      dunk  \
# 0          1   -1.404366    1.173298     0.782339 -0.531846 -0.200886
# 1          1   -1.404366    1.173298     0.782339 -0.531846 -0.200886
# 2          1   -1.404366    1.173298     0.782339  1.880218 -0.200886
# 3          1   -1.404366    1.173298     0.782339  1.880218 -0.200886
# 4          1   -1.404366    1.173298     0.782339 -0.531846 -0.200886
#
#        hook  fadeaway   pullup   running  ...    End_SC    End_PC  LOCATION  \
# 0 -0.183868 -0.155562 -0.21311 -0.195315  ... -0.295785 -0.033428  0.982177
# 1 -0.183868  6.428227 -0.21311 -0.195315  ... -0.295785 -0.033428  0.982177
# 2 -0.183868 -0.155562 -0.21311 -0.195315  ... -0.295785 -0.033428  0.982177
# 3 -0.183868 -0.155562 -0.21311  5.119866  ... -0.295785 -0.033428 -1.018132
# 4 -0.183868 -0.155562 -0.21311 -0.195315  ...  3.380790 -0.033428  0.982177
#
#     Quick_S  Clutch_T  Garbage_T  SHOT_CLOCK  SHOT_NUMBER  SHOT_RESULT2  \
# ...

# %%
test_ordered["Player_ID"] = 1
test_ordered.head()
# Out:
# C:\Users\james\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    Intercept  FG_Percent  FT_Percent  FG3_Percent     layup      dunk  \
# 0          1   -1.404366    1.173298     0.782339 -0.531846 -0.200886
# 1          1   -1.404366    1.173298     0.782339 -0.531846 -0.200886
# 2          1   -1.404366    1.173298     0.782339  1.880218 -0.200886
# 3          1   -1.404366    1.173298     0.782339  1.880218 -0.200886
# 4          1   -1.404366    1.173298     0.782339 -0.531846 -0.200886
#
#        hook  fadeaway   pullup   running  ...    End_PC  LOCATION   Quick_S  \
# 0 -0.183868 -0.155562 -0.21311 -0.195315  ... -0.033428  0.982177 -0.423231
# ...

# %%
id = 1
name = "aaron brooks"
for index, row in test_ordered.iterrows():
    if row["player_name"] is name:
        test_ordered[row["Player_ID"]] = id
    else:
        id += 1
        name = row["player_name"]
        test_ordered[row["Player_ID"]] = id
# Out:
# C:\Users\james\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\james\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
test_ordered
